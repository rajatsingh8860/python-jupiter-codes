# %%
import matplotlib.pyplot as plt
activities=['eat','sleep','work','play']
slices=[3,6,8,9]
color=['r','g','m','b']
plt.pie(slices,labels=activities,colors=color,startangle=90,shadow=True,explode=(0.3,0,0,0),autopct='%1.2f%%')
plt.legend()
plt.show()
